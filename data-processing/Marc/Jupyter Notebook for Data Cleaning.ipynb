# %%
import pandas as pd

# %%
file = pd.read_excel(r'C:\Users\Yash\Desktop\McMaster Material\Project\My Dataset.xlsx')

# %%
file.head()
# Out:
#                                                 ISBN                   Author  \
# 0                                          850450926           Hoffmann, Ann.
# 1                                                NaN              Weber, Jan.
# 2                                          809307472  Latzer, Beth Good,1911-
# 3  0394900383(lib.bdg.);0394800389 (trade);978039...                Seuss,Dr.
# 4         0138516006 (lib. bdg. :){dollar}6.95;19.75     DePaola, Tomie,1934-
#
#                                                Title  \
# 0  Lives of the Tudor age, 1485-1603 /by Ann Hoff...
# 1  The Hamilton Public Library :audio visual pres...
# 2  Myrtleville :a Canadian farm and family, 1837-...
# 3                        Fox in socks /by Dr. Seuss.
# 4  Strega Nona :an old tale /retold and illustrat...
#
#                            Topical Term
# 0                                   NaN
# 1  Public libraries--Ontario--Hamilton.
# 2                                   NaN
# ...

# %%
file.isnull()
# Out:
#          ISBN  Author  Title  Topical Term
# 0       False   False  False          True
# 1        True   False  False         False
# 2       False   False  False          True
# 3       False   False  False         False
# 4       False   False  False         False
# ...       ...     ...    ...           ...
# 395871  False   False  False          True
# 395872  False   False  False          True
# 395873   True    True  False          True
# 395874  False   False  False         False
# 395875   True   False  False          True
#
# [395876 rows x 4 columns]

# %%
modifiedfile = file.dropna()

# %%
modifiedfile.isnull().sum()
# Out:
# ISBN            0
# Author          0
# Title           0
# Topical Term    0
# dtype: int64

# %%
modifiedfile.isnull()
# Out:
#          ISBN  Author  Title  Topical Term
# 3       False   False  False         False
# 4       False   False  False         False
# 13      False   False  False         False
# 18      False   False  False         False
# 25      False   False  False         False
# ...       ...     ...    ...           ...
# 395842  False   False  False         False
# 395843  False   False  False         False
# 395844  False   False  False         False
# 395845  False   False  False         False
# 395874  False   False  False         False
#
# [262742 rows x 4 columns]

# %%
modifiedfile.to_excel(r'C:\Users\Yash\Desktop\McMaster Material\Project\New Dataset.xlsx',index=False)

# %%
new_file = pd.read_excel(r'C:\Users\Yash\Desktop\McMaster Material\Project\New Dataset.xlsx')

# %%
new_file.head()
# Out:
#                                                 ISBN  \
# 0  0394900383(lib.bdg.);0394800389 (trade);978039...
# 1         0138516006 (lib. bdg. :){dollar}6.95;19.75
# 2                                              15.02
# 3                                        9.19676e+09
# 4                                      9780064440172
#
#                        Author  \
# 0                   Seuss,Dr.
# 1        DePaola, Tomie,1934-
# 2                 Zion, Gene.
# 3          Nielsen, Robert F.
# 4  Bonsall, Crosby,1921-1995.
#
#                                                Title  \
# 0                        Fox in socks /by Dr. Seuss.
# 1  Strega Nona :an old tale /retold and illustrat...
# 2  Harry and the lady next door /by Gene Zion ; p...
# 3  Garney Henley :a gentleman and a tiger /by Rob...
# 4     The case of the cat's meow /by Crosby Bonsall.
#
#                                         Topical Term
# 0                                   Nonsense verses.
# ...

# %%
updated = new_file['Title'].str.extract(r'(.*)/[^/]*', expand=False)

# %%
updated.head()
# Out:
# 0                              Fox in socks
# 1                  Strega Nona :an old tale
# 2              Harry and the lady next door
# 3    Garney Henley :a gentleman and a tiger
# 4                The case of the cat's meow
# Name: Title, dtype: object

# %%
updated.to_excel(r'C:\Users\Yash\Desktop\McMaster Material\Project\New.xlsx',index=True)

# %%
updated.isnull().sum()
# Out:
# 20421

# %%
latest = pd.read_excel(r'C:\Users\Yash\Desktop\McMaster Material\Project\New Dataset - 1.xlsx')

# %%
latest.isnull()
# Out:
#          ISBN  Author  Title  Topical Term
# 0       False   False  False         False
# 1       False   False  False         False
# 2       False   False  False         False
# 3       False   False  False         False
# 4       False   False  False         False
# ...       ...     ...    ...           ...
# 262737  False   False  False         False
# 262738  False   False  False         False
# 262739  False   False  False         False
# 262740  False   False  False         False
# 262741  False   False  False         False
#
# [262742 rows x 4 columns]

# %%
modifiedlatest = latest.dropna()

# %%
modifiedlatest.isnull().sum()
# Out:
# ISBN            0
# Author          0
# Title           0
# Topical Term    0
# dtype: int64

# %%
modifiedlatest.to_excel(r'C:\Users\Yash\Desktop\McMaster Material\Project\Latest Dataset.xlsx',index=False)

# %%
modifiedlatest.isnull()
# Out:
#          ISBN  Author  Title  Topical Term
# 0       False   False  False         False
# 1       False   False  False         False
# 2       False   False  False         False
# 3       False   False  False         False
# 4       False   False  False         False
# ...       ...     ...    ...           ...
# 262737  False   False  False         False
# 262738  False   False  False         False
# 262739  False   False  False         False
# 262740  False   False  False         False
# 262741  False   False  False         False
#
# [242321 rows x 4 columns]
